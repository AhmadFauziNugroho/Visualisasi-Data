# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmadFauziNugroho/Visualisasi-Data/blob/main/praktikum06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Praktikum 06 - Stacked Vertical Bar Chart
#
# Kelompok 30:
#
# *   KAYS ELHAQ RABBANI (0110222218)
# *   AHMAD FAUZI NUGROHO (0110222293)
# *   MUHAMMAD AL FARUQ (0110122057)

# %% [markdown]
# **1. Import lib**

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **2. Dataset**

# %%
# dataset
stores = ['Store A', 'Store B', 'Store C']
male = [150, 200, 250]
female = [120, 240, 180]

# data quarter
q1_male = [150, 180, 160]
q1_female = [140, 200, 180]
q2_male = [170, 190, 175]
q2_female = [130, 210, 160]
q3_male = [160, 180, 170]
q3_female = [150, 200, 190]
q4_male = [180, 200, 190]
q4_female = [160, 190, 180]

# %% [markdown]
# **3. Basic Stacked Vertical Bar Chart**

# %%
x = np.arange(len(stores))
plt.bar(x, male, label="Male", color="darkblue")
plt.bar(x, female, bottom=male, label='Female', color="darkred")

plt.title('Population by Gender and Store')
plt.xlabel('Stores')
plt.ylabel('Population')
plt.xticks(x, stores)
plt.legend()
plt.show()

# %% [markdown]
# **4. Kustomisasi Stacked Vertical Bar Chart**

# %%
x = np.arange(len(stores))
plt.bar(x, male, label="Male", color="darkblue")
plt.bar(x, female, bottom=male, label='Female', color="darkred")

plt.title('Population by Gender and Store')
plt.xlabel('Stores')
plt.ylabel('Population')
plt.xticks(x, stores)
plt.legend()

for i in range(len(x)):
    plt.text(x[i], male[i]/2, str(male[i]), ha='center', color='white')
    plt.text(x[i], male[i] + female[i]/2, str(female[i]), ha='center', color='black')

plt.show()

# %% [markdown]
# **5. Multiple Stacked Vertical Bar Chart**

# %%
width = 0.2
x = np.arange(len(stores))

plt.bar(x-width * 1.5, q1_male, label= 'q1_male', color='purple', width=width)
plt.bar(x-width * 1.5, q1_female, bottom=q1_male, label='q1_female', color='lightblue', width=width)

plt.bar(x+width/2, q2_male, label= 'q2_male', color='navy', width=width)
plt.bar(x+width/2, q2_female, bottom= q2_male, label='q2_female', color='grey', width=width)

plt.bar(x-width/2, q3_male, label= 'q3_male', color='lightpink', width=width)
plt.bar(x-width/2, q3_female, bottom=q3_male, label='q3_female', color='lightgreen', width=width)

plt.bar(x+width * 1.5, q4_male, label= 'q4_male', color='green', width=width)
plt.bar(x+width * 1.5, q4_female, bottom= q4_male, label='q4_female', color='aquamarine', width=width)

plt.title('Population by Gender and Store (Multiple Quarter)')
plt.xlabel('Stores')
plt.ylabel('Population')
plt.xticks(x, stores)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()
